# %%
import pandas as pd

# %%
df = pd.DataFrame({'Date':['2020-10-11','2020-10-12','2020-10-13'], 'Close':['12','13','14']})

# %%
df
# Out:
#          Date Close
# 0  2020-10-11    12
# 1  2020-10-12    13
# 2  2020-10-13    14

# %%
df.append({'Date': '2020-10-14', 'Close':'NaN'}, ignore_index=True)
# Out:
#          Date Close
# 0  2020-10-11    12
# 1  2020-10-12    13
# 2  2020-10-13    14
# 3  2020-10-14   NaN

# %%
df.set_index('Date')
# Out:
#            Close
# Date
# 2020-10-11    12
# 2020-10-12    13
# 2020-10-13    14

# %%
df
# Out:
#          Date Close
# 0  2020-10-11    12
# 1  2020-10-12    13
# 2  2020-10-13    14

# %%
import pandas_datareader as pdd
# here we are importing important libraries
import math
import pandas_datareader as pdd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.optimize as sco

from datetime import datetime
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense,LSTM
from pandas_datareader import data as web
from pypfopt.efficient_frontier import EfficientFrontier
from pypfopt import risk_models
from pypfopt import expected_returns

# %%
df = pdd.DataReader('AAPL', data_source = 'yahoo', start = '2020-01-01')
df
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2020-01-02   75.150002   73.797501   74.059998   75.087502  135480400.0
# 2020-01-03   75.144997   74.125000   74.287498   74.357498  146322800.0
# 2020-01-06   74.989998   73.187500   73.447502   74.949997  118387200.0
# 2020-01-07   75.224998   74.370003   74.959999   74.597504  108872000.0
# 2020-01-08   76.110001   74.290001   74.290001   75.797501  132079200.0
# ...                ...         ...         ...         ...          ...
# 2020-11-05  119.620003  116.870003  117.949997  119.029999  126387100.0
# 2020-11-06  119.199997  116.129997  118.320000  118.690002  114457900.0
# 2020-11-09  121.989998  116.050003  120.500000  116.320000  154515300.0
# 2020-11-10  117.589996  114.129997  115.550003  115.970001  137656000.0
# 2020-11-11  119.559998  116.440002  117.190002  118.989998   87837199.0
#
#              Adj Close
# Date
# 2020-01-02   73.840042
# 2020-01-03   73.122154
# 2020-01-06   73.704819
# 2020-01-07   73.358185
# 2020-01-08   74.538239
# ...                ...
# 2020-11-05  118.824997
# 2020-11-06  118.690002
# 2020-11-09  116.320000
# 2020-11-10  115.970001
# 2020-11-11  118.989998
#
# [219 rows x 6 columns]

# %%
# Visualization of close price data

plt.figure(figsize=(16,8))
plt.plot(df['Close'])
plt.show()

# %%
dff= df[['Close']]
dff.head()
# Out:
#                 Close
# Date
# 2020-01-02  75.087502
# 2020-01-03  74.357498
# 2020-01-06  74.949997
# 2020-01-07  74.597504
# 2020-01-08  75.797501

# %%
#creating a variable to perdict x days out into the future

future_days = 30

#creating a new column (target) sgifted 'x' units/days up

dff['Predict'] = df[['Close']].shift(-future_days)

dff.tail()
# Out:
# <ipython-input-43-e0dd5026740c>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dff['Predict'] = df[['Close']].shift(-future_days)
#                  Close  Predict
# Date
# 2020-11-05  119.029999      NaN
# 2020-11-06  118.690002      NaN
# 2020-11-09  116.320000      NaN
# 2020-11-10  115.970001      NaN
# 2020-11-11  118.989998      NaN

# %%
# create a feature data set (x) and convert it to a numpy array

x = np.array

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas_datareader as pdd
from sklearn import metrics
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pdd.DataReader('AAPL', data_source = 'yahoo', start = '2020-01-01')
df.head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2020-01-02  75.150002  73.797501  74.059998  75.087502  135480400.0  73.840042
# 2020-01-03  75.144997  74.125000  74.287498  74.357498  146322800.0  73.122154
# 2020-01-06  74.989998  73.187500  73.447502  74.949997  118387200.0  73.704819
# 2020-01-07  75.224998  74.370003  74.959999  74.597504  108872000.0  73.358185
# 2020-01-08  76.110001  74.290001  74.290001  75.797501  132079200.0  74.538239

# %%
from sklearn.preprocessing import Normalizer
for column in df.columns:
    if df[column].dtype == type(object):
        le = sk.preprocessing.LabelEncoder()
        df[column] = le.fit_transform(df[column])
        
df.head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2020-01-02  75.150002  73.797501  74.059998  75.087502  135480400.0  73.840042
# 2020-01-03  75.144997  74.125000  74.287498  74.357498  146322800.0  73.122154
# 2020-01-06  74.989998  73.187500  73.447502  74.949997  118387200.0  73.704819
# 2020-01-07  75.224998  74.370003  74.959999  74.597504  108872000.0  73.358185
# 2020-01-08  76.110001  74.290001  74.290001  75.797501  132079200.0  74.538239

# %%
df_x = df[['High','Low','Open','Volume']]
df_y = df['Close']

# %%
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# x_scaled = scaler.fit_transform(df_x)
# x_train, x_test, y_train, y_test = train_test_split(x_scaled, df_y, test_size=0.25, random_state=42)

# %%
x_train, x_test, y_train, y_test = train_test_split(df_x, df_y, test_size=0.25, random_state=42)

# %%
x_train
# Out:
#                   High         Low        Open       Volume
# Date
# 2020-02-13   81.555000   80.837502   81.047501   94747600.0
# 2020-01-30   81.022499   79.687500   80.135002  126743200.0
# 2020-04-13   68.425003   66.457497   67.077499  131022800.0
# 2020-10-22  118.040001  114.589996  117.449997  101988000.0
# 2020-03-30   63.880001   62.349998   62.685001  167976400.0
# ...                ...         ...         ...          ...
# 2020-06-04   81.404999   80.195000   81.097504   87560400.0
# 2020-01-23   79.889999   78.912498   79.480003  104472000.0
# 2020-05-14   77.447502   75.382500   76.127502  158929200.0
# 2020-09-17  112.199997  108.709999  109.720001  178011000.0
# 2020-05-29   80.287498   79.117500   79.812500  153598000.0
#
# [164 rows x 4 columns]

# %%
reg = LinearRegression().fit(x_train, y_train)
reg_pred = reg.predict(x_test)

# %%
print("Accuracy score::", reg.score(x_test,y_test))
# Out:
# Accuracy score:: 0.9967482287145809

# %%
dframe = pd.DataFrame({'Actual':y_test,'Predicted': reg_pred})
dframe = dframe.sort_index()
dframe.head()
# Out:
#                Actual  Predicted
# Date
# 2020-01-15  77.834999  78.271412
# 2020-01-24  79.577499  80.164951
# 2020-01-27  77.237503  76.839814
# 2020-01-29  81.084999  81.174355
# 2020-02-06  81.302498  80.769138

# %%
print(metrics.mean_absolute_error(y_test,reg_pred))
print(metrics.mean_squared_error(y_test,reg_pred))
print(math.sqrt(metrics.mean_squared_error(y_test,reg_pred)))
# Out:
# 0.719916620456046
# 1.2147496285917647
# 1.1021568076239263

# %%
dframe.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df = pdd.DataReader('AAPL', data_source = 'yahoo', start = '2020-01-01')
df.head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2020-01-02  75.150002  73.797501  74.059998  75.087502  135480400.0  73.840042
# 2020-01-03  75.144997  74.125000  74.287498  74.357498  146322800.0  73.122154
# 2020-01-06  74.989998  73.187500  73.447502  74.949997  118387200.0  73.704819
# 2020-01-07  75.224998  74.370003  74.959999  74.597504  108872000.0  73.358185
# 2020-01-08  76.110001  74.290001  74.290001  75.797501  132079200.0  74.538239

# %%
lastest_value = df['Close'].tail(1)
dff.tail()
# Out:
#                  Close        Pred
# Date
# 2020-11-05  119.029999         NaN
# 2020-11-06  118.690002         NaN
# 2020-11-09  116.320000         NaN
# 2020-11-10  115.970001         NaN
# 2020-11-11  118.989998  119.489998

# %%
df.loc[len(df.index)] = []

# %%
value = dff['Pred'].tail(1)
value
# Out:
# Date
# 2020-11-11    119.489998
# Name: Pred, dtype: float64

# %%
df.tail()
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2020-11-05  119.620003  116.870003  117.949997  119.029999  126387100.0
# 2020-11-06  119.199997  116.129997  118.320000  118.690002  114457900.0
# 2020-11-09  121.989998  116.050003  120.500000  116.320000  154515300.0
# 2020-11-10  117.589996  114.129997  115.550003  115.970001  137656000.0
# 2020-11-11  119.628197  116.440002  117.190002  119.489998  109791495.0
#
#              Adj Close
# Date
# 2020-11-05  118.824997
# 2020-11-06  118.690002
# 2020-11-09  116.320000
# 2020-11-10  115.970001
# 2020-11-11  119.489998

# %%
value = df[['High','Low','Open','Volume']].tail(5)

# %%
reg_pred = reg.predict(value)

# %%
reg_pred
# Out:
# array([118.52065642, 117.38086573, 118.182487  , 116.12119264,
#        118.63340373])

# %%
dframe = pd.DataFrame({'Actual':df['Close'].tail(5),'Predicted': reg_pred})
dframe
# Out:
#                 Actual   Predicted
# Date
# 2020-11-05  119.029999  118.520656
# 2020-11-06  118.690002  117.380866
# 2020-11-09  116.320000  118.182487
# 2020-11-10  115.970001  116.121193
# 2020-11-11  119.489998  118.633404

# %%
# Out:
# 1

# %%
dframe.loc[len(dframe.index)+1] = [118,119]
dframe
# Out:
#                          Actual   Predicted
# Date
# 2020-11-05 00:00:00  119.029999  118.520656
# 2020-11-06 00:00:00  118.690002  117.380866
# 2020-11-09 00:00:00  116.320000  118.182487
# 2020-11-10 00:00:00  115.970001  116.121193
# 2020-11-11 00:00:00  119.489998  118.633404
# 6                    118.000000  119.000000

# %%
#now we are Building the LSTM network model
model = Sequential()

#Adding the first LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences=True,input_shape=(x_train.shape[1],1)))
model.add(Dropout(0.2))

# Adding a second LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences=True))
model.add(Dropout(0.2))

# Adding a third LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences=True))
model.add(Dropout(0.2))

# Adding a forth LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences=True))
model.add(Dropout(0.2))

# Addding the output layer
model.add(Dense(units = 1))
